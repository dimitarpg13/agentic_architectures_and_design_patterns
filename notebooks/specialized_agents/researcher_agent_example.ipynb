# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitarpg13/agentic_architectures_and_design_patterns/blob/main/notebooks/specialized_agents/researcher_agent_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔬 Researcher Agent with LangGraph
#
# This notebook demonstrates building an intelligent **Researcher Agent** using LangGraph and LangChain that can:
#
# - Accept natural language research queries
# - Search the web for relevant information
# - Synthesize findings into comprehensive research reports
#
# ## Architecture Overview
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │                    RESEARCHER AGENT                         │
# ├─────────────────────────────────────────────────────────────┤
# │                                                             │
# │   [Query] ──► [Planner] ──► [Web Search] ──► [Synthesizer]  │
# │                   │              │               │          │
# │                   ▼              ▼               ▼          │
# │              Research        Search          Final          │
# │               Plan          Results         Report          │
# │                                                             │
# └─────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ## 1. Environment Setup
#
# First, let's install the required dependencies.

# %%
# Install required packages
# !pip install -q langchain langchain-openai langchain-anthropic langchain-google-genai langgraph tavily-python

# %%
import os
from typing import Annotated, List, TypedDict, Literal
from datetime import datetime

# LangChain imports
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.tools import tool

# LangGraph imports
from langgraph.graph import StateGraph, END, START
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition

# Web search
from tavily import TavilyClient

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## 2. API Key Configuration
#
# Set up your API keys. You can use **OpenAI**, **Anthropic**, or **Google Gemini** as the LLM backend.
#
# For web search, we use **Tavily** (get a free API key at https://tavily.com)

# %%
# Option 1: Set API keys directly (not recommended for production)
# os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
# os.environ["ANTHROPIC_API_KEY"] = "your-anthropic-api-key"
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"
# os.environ["TAVILY_API_KEY"] = "your-tavily-api-key"

# Option 2: Use getpass for secure input
from getpass import getpass

# Choose your LLM provider
LLM_PROVIDER = "openai"  # Options: "openai", "anthropic", "google"

if LLM_PROVIDER == "openai" and "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")
elif LLM_PROVIDER == "anthropic" and "ANTHROPIC_API_KEY" not in os.environ:
    os.environ["ANTHROPIC_API_KEY"] = getpass("Enter your Anthropic API key: ")
elif LLM_PROVIDER == "google" and "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass("Enter your Google API key: ")

if "TAVILY_API_KEY" not in os.environ:
    os.environ["TAVILY_API_KEY"] = getpass("Enter your Tavily API key: ")

print(f"✅ Configured for {LLM_PROVIDER.upper()} with Tavily web search")
# Out:
# Enter your OpenAI API key: ··········
# Enter your Tavily API key: ··········
# ✅ Configured for OPENAI with Tavily web search

# %% [markdown]
# ## 3. Initialize the LLM
#
# We support multiple LLM providers. Select one based on your preference.

# %%
def get_llm(provider: str = "openai"):
    """Initialize the LLM based on the selected provider."""

    if provider == "openai":
        from langchain_openai import ChatOpenAI
        return ChatOpenAI(
            model="gpt-4o",
            temperature=0.7,
        )

    elif provider == "anthropic":
        from langchain_anthropic import ChatAnthropic
        return ChatAnthropic(
            model="claude-sonnet-4-20250514",
            temperature=0.7,
        )

    elif provider == "google":
        from langchain_google_genai import ChatGoogleGenerativeAI
        return ChatGoogleGenerativeAI(
            model="gemini-1.5-pro",
            temperature=0.7,
        )

    else:
        raise ValueError(f"Unknown provider: {provider}")

# Initialize the LLM
llm = get_llm(LLM_PROVIDER)
print(f"✅ LLM initialized: {llm.model_name if hasattr(llm, 'model_name') else LLM_PROVIDER}")
# Out:
# ✅ LLM initialized: gpt-4o

# %% [markdown]
# ## 4. Define Web Search Tools
#
# We'll create a powerful web search tool using the Tavily API.

# %%
# Initialize Tavily client
tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

@tool
def web_search(query: str) -> str:
    """Search the web for current information on a given topic.

    Args:
        query: The search query to look up on the web.

    Returns:
        A summary of search results with relevant information.
    """
    try:
        # Perform the search
        response = tavily_client.search(
            query=query,
            search_depth="advanced",
            max_results=5,
            include_answer=True,
            include_raw_content=False,
        )

        # Format the results
        results = []

        # Include the AI-generated answer if available
        if response.get("answer"):
            results.append(f"**Quick Answer:** {response['answer']}\n")

        # Include individual search results
        results.append("**Search Results:**\n")
        for i, result in enumerate(response.get("results", []), 1):
            title = result.get("title", "No title")
            url = result.get("url", "")
            content = result.get("content", "No content available")
            results.append(f"{i}. **{title}**\n   URL: {url}\n   {content}\n")

        return "\n".join(results)

    except Exception as e:
        return f"Search error: {str(e)}"


@tool
def get_current_date() -> str:
    """Get the current date and time for context in research.

    Returns:
        The current date and time as a formatted string.
    """
    return datetime.now().strftime("%B %d, %Y at %H:%M")


# List of tools available to the agent
tools = [web_search, get_current_date]

print("✅ Tools defined:")
for t in tools:
    print(f"   - {t.name}: {t.description[:60]}...")
# Out:
# ✅ Tools defined:
#    - web_search: Search the web for current information on a given topic.
#
#   ...
#    - get_current_date: Get the current date and time for context in research.
#
#     ...

# %% [markdown]
# ## 5. Define Agent State
#
# LangGraph uses a typed state object to track the agent's progress through the workflow.

# %%
class ResearcherState(TypedDict):
    """State object for the Researcher Agent.

    Attributes:
        messages: The conversation history with tool calls and responses
        research_query: The original research query from the user
        research_plan: The generated plan for conducting research
        search_results: Accumulated search results
        final_report: The synthesized research report
        iteration_count: Number of research iterations performed
    """
    messages: Annotated[list, add_messages]
    research_query: str
    research_plan: str
    search_results: List[str]
    final_report: str
    iteration_count: int

print("✅ State schema defined")
# Out:
# ✅ State schema defined

# %% [markdown]
# ## 6. Define Agent Nodes
#
# Each node represents a distinct step in the research workflow.

# %%
# System prompts for different agent roles

PLANNER_PROMPT = """You are a research planning expert. Your job is to analyze a research query
and create a structured plan for investigating the topic.

Given the user's research query, create a clear plan that includes:
1. Key aspects of the topic to investigate
2. Specific search queries to execute (2-4 queries)
3. What information to look for in each search

Keep the plan focused and actionable. Format it clearly with numbered steps.

Research Query: {query}
"""

RESEARCHER_PROMPT = """You are an expert researcher with access to web search tools.
Your goal is to find accurate, up-to-date information on the given topic.

Research Plan:
{plan}

Use the web_search tool to find relevant information. Search systematically according
to the research plan. Be thorough but focused.

When you have gathered enough information (typically 2-3 searches), indicate that
you're ready to synthesize by saying "RESEARCH COMPLETE".
"""

SYNTHESIZER_PROMPT = """You are an expert at synthesizing research findings into clear,
comprehensive reports.

Original Query: {query}

Research Findings:
{findings}

Create a well-structured research report that:
1. Provides a clear executive summary
2. Organizes findings into logical sections
3. Highlights key insights and facts
4. Notes any limitations or areas needing further research
5. Includes relevant sources where applicable

Format the report professionally with headers and bullet points.
"""

print("✅ Prompts defined")
# Out:
# ✅ Prompts defined

# %%
def plan_research(state: ResearcherState) -> ResearcherState:
    """Create a research plan based on the query."""
    print("📋 Planning research...")

    query = state["research_query"]

    # Generate research plan
    plan_prompt = ChatPromptTemplate.from_template(PLANNER_PROMPT)
    chain = plan_prompt | llm | StrOutputParser()
    plan = chain.invoke({"query": query})

    print(f"\n{plan}\n")

    return {
        **state,
        "research_plan": plan,
        "messages": [
            SystemMessage(content=RESEARCHER_PROMPT.format(plan=plan)),
            HumanMessage(content=f"Please research: {query}")
        ],
    }


def conduct_research(state: ResearcherState) -> ResearcherState:
    """Agent node that decides whether to search or synthesize."""
    print(f"🔍 Researching (iteration {state['iteration_count'] + 1})...")

    # Bind tools to the LLM
    llm_with_tools = llm.bind_tools(tools)

    # Get the agent's response
    response = llm_with_tools.invoke(state["messages"])

    return {
        **state,
        "messages": [response],
        "iteration_count": state["iteration_count"] + 1,
    }


def synthesize_report(state: ResearcherState) -> ResearcherState:
    """Synthesize all research findings into a final report."""
    print("📝 Synthesizing final report...")

    # Extract all search results from messages
    findings = []
    for msg in state["messages"]:
        if hasattr(msg, 'content') and msg.content:
            # Look for tool results (search results)
            if isinstance(msg.content, str) and "Search Results" in msg.content:
                findings.append(msg.content)
            elif hasattr(msg, 'tool_calls') or "**" in str(msg.content):
                findings.append(str(msg.content))

    # Combine all findings
    all_findings = "\n\n---\n\n".join(findings) if findings else "No specific findings collected."

    # Generate the final report
    synth_prompt = ChatPromptTemplate.from_template(SYNTHESIZER_PROMPT)
    chain = synth_prompt | llm | StrOutputParser()

    report = chain.invoke({
        "query": state["research_query"],
        "findings": all_findings
    })

    return {
        **state,
        "final_report": report,
        "messages": [AIMessage(content=report)],
    }


print("✅ Agent nodes defined")
# Out:
# ✅ Agent nodes defined

# %% [markdown]
# ## 7. Define Routing Logic
#
# The router determines the next step based on the current state.

# %%
def should_continue_research(state: ResearcherState) -> Literal["tools", "synthesize"]:
    """Determine whether to continue researching or synthesize results."""

    messages = state["messages"]
    last_message = messages[-1]

    # Check if we've hit the iteration limit
    if state["iteration_count"] >= 5:
        print("⏹️ Max iterations reached, moving to synthesis...")
        return "synthesize"

    # Check if the agent wants to use tools
    if hasattr(last_message, 'tool_calls') and last_message.tool_calls:
        print(f"🔧 Agent requesting tool: {last_message.tool_calls[0]['name']}")
        return "tools"

    # Check if research is complete
    if hasattr(last_message, 'content') and "RESEARCH COMPLETE" in str(last_message.content).upper():
        print("✅ Research complete, moving to synthesis...")
        return "synthesize"

    # Default: continue to synthesis if no tools needed
    return "synthesize"


print("✅ Routing logic defined")
# Out:
# ✅ Routing logic defined

# %% [markdown]
# ## 8. Build the LangGraph Workflow
#
# Now we assemble all components into a complete graph.

# %%
def build_researcher_agent():
    """Construct the Researcher Agent graph."""

    # Create the graph
    workflow = StateGraph(ResearcherState)

    # Add nodes
    workflow.add_node("planner", plan_research)
    workflow.add_node("researcher", conduct_research)
    workflow.add_node("tools", ToolNode(tools))
    workflow.add_node("synthesizer", synthesize_report)

    # Define the workflow edges
    workflow.add_edge(START, "planner")
    workflow.add_edge("planner", "researcher")

    # Conditional routing from researcher
    workflow.add_conditional_edges(
        "researcher",
        should_continue_research,
        {
            "tools": "tools",
            "synthesize": "synthesizer",
        }
    )

    # After tools, go back to researcher
    workflow.add_edge("tools", "researcher")

    # Synthesizer ends the workflow
    workflow.add_edge("synthesizer", END)

    # Compile the graph
    return workflow.compile()


# Build the agent
researcher_agent = build_researcher_agent()

print("✅ Researcher Agent built successfully!")
# Out:
# ✅ Researcher Agent built successfully!

# %%
# Visualize the graph (optional - requires graphviz)
try:
    from IPython.display import Image, display
    display(Image(researcher_agent.get_graph().draw_mermaid_png()))
except Exception as e:
    print("Graph visualization not available. Install graphviz for visualization.")
    print("\nWorkflow structure:")
    print("START → planner → researcher ⟷ tools → synthesizer → END")

# %% [markdown]
# ## 9. Run the Researcher Agent
#
# Let's test our agent with a research query!

# %%
def run_research(query: str) -> str:
    """Execute a research query and return the final report.

    Args:
        query: The research question or topic to investigate.

    Returns:
        The final research report as a string.
    """
    print("="*60)
    print(f"🔬 RESEARCH AGENT")
    print("="*60)
    print(f"\n📌 Query: {query}\n")
    print("-"*60)

    # Initialize state
    initial_state = {
        "messages": [],
        "research_query": query,
        "research_plan": "",
        "search_results": [],
        "final_report": "",
        "iteration_count": 0,
    }

    # Run the agent
    final_state = researcher_agent.invoke(initial_state)

    print("\n" + "="*60)
    print("📄 FINAL RESEARCH REPORT")
    print("="*60)
    print(final_state["final_report"])

    return final_state["final_report"]

# %%
# Example Research Query 1: Technology
report = run_research(
    "What are the latest developments in AI agents and autonomous systems in 2025? "
    "Focus on practical applications and key players in the industry."
)
# Out:
# ============================================================
# 🔬 RESEARCH AGENT
# ============================================================
#
# 📌 Query: What are the latest developments in AI agents and autonomous systems in 2025? Focus on practical applications and key players in the industry.
#
# ------------------------------------------------------------
# 📋 Planning research...
#
# **Research Plan for Investigating Developments in AI Agents and Autonomous Systems in 2025**
#
# **1. Key Aspects to Investigate:**
#    - Current trends and advancements in AI agents and autonomous systems as of 2025.
#    - Practical applications of AI agents and autonomous systems across various industries.
#    - Key players and emerging companies leading the development and deployment of these technologies.
#    - Challenges and limitations faced by AI agents and autonomous systems in practical applications.
#
# **2. Specific Search Queries to Execute:**
#
#    - **Query 1:** "AI agents and autonomous systems advancements 2025"
#      - **Information to Look For:** Recent technological advancements and breakthroughs in AI agents and autonomous systems. Look for articles, reports, and expert analyses published in 2025 that discuss the state-of-the-art technologies and their potential impact on various sectors.
#
#    - **Query 2:** "Practical applications of AI agents and autonomous systems 2025"
#      - **Information to Look For:** Case studies, examples, and reports highlighting how AI agents and autonomous systems are being utilized in real-world scenarios. Focus on industries such as healthcare, transportation, manufacturing, and finance, and how these systems are enhancing efficiency and productivity.
#
#    - **Query 3:** "Key players in AI agents and autonomous systems 2025"
#      - **Information to Look For:** Identify major companies, startups, and research institutions that are at the forefront of developing AI agents and autonomous systems. Look for information on collaborations, funding rounds, and strategic initiatives that indicate leadership in the field.
#
#    - **Query 4:** "Challenges and limitations of AI agents and autonomous systems 2025"
#      - **Information to Look For:** Discussions on the current challenges faced by AI agents and autonomous systems in terms of technology, ethics, regulation, and societal impact. Look for expert opinions, white papers, and industry reports that analyze these challenges and propose potential solutions.
#
# **3. Additional Steps:**
#    - Compile information obtained from the searches into a comprehensive overview.
#    - Identify any gaps in the research and perform additional searches as needed.
#    - Analyze the findings to identify patterns and insights regarding the trajectory of AI agents and autonomous systems in 2025.
#
# 🔍 Researching (iteration 1)...
# 🔧 Agent requesting tool: web_search
# 🔍 Researching (iteration 2)...
# ✅ Research complete, moving to synthesis...
# 📝 Synthesizing final report...
#
# ============================================================
# 📄 FINAL RESEARCH REPORT
# ============================================================
# # Research Report: Developments in AI Agents and Autonomous Systems in 2025
#
# ## Executive Summary
#
# In 2025, the landscape of AI agents and autonomous systems experienced significant advancements. These systems evolved from simple task automation tools to sophisticated, autonomous entities capable of complex decision-making and independent operation. This report synthesizes the latest developments, practical applications, and key industry players, while also highlighting the challenges and future trends in the field.
#
# ## 1. Introduction
#
# The field of AI agents and autonomous systems has reached a pivotal point in 2025. This report explores the current state of these technologies, their applications across various industries, and the key players driving innovation. It also addresses the challenges faced by these systems and the trends expected to shape their future development.
#
# ## 2. Advancements and Applications
#
# ### 2.1 Technological Advancements
# - **Oracle's Miracle Agent**: Automates workflows across finance, HR, and supply chain by processing structured and unstructured data autonomously within Oracle's Fusion Cloud suite.
# - **NVIDIA's Eureka**: Utilizes GPT-4 for autonomous robot training, enhancing manufacturing and logistics through reinforcement learning.
# - **SAP's Joule**: Provides enterprise insights and recommendations using LLMs like Llama 3, integrated across various business functions.
# - **Salesforce Agentforce 2.0**: Delivers virtual sales, support, and service roles within the Salesforce ecosystem, integrating deeply with CRM systems.
#
# ### 2.2 Practical Applications
# - **Marketing Automation**: AI agents automate routine tasks, allowing marketing teams to focus on strategic goals and improving campaign planning.
# - **Data Analysis**: Agents analyze complex data sets autonomously, providing insights and reducing human error.
# - **Software Development**: AI-driven agents contribute to code generation, bug fixes, and application deployment.
# - **Customer Support**: Agents handle queries, ticket resolutions, and provide real-time support, freeing human agents for more complex issues.
#
# ## 3. Key Industry Players
#
# ### 3.1 Leading Companies
# - **IBM**: Advances its Watson AI into agentic AI with Watsonx, serving industries like cloud, cybersecurity, and healthcare.
# - **Infosys**: Through its Topaz platform, integrates generative AI with AI agents for enterprise solutions, focusing on customer support and fraud detection.
# - **Salesforce**: Enhances CRM integration with Agentforce, providing role-based AI agents.
# - **Fujitsu's Kozuchi**: Supports strategic decision-making in compliance-heavy environments.
#
# ### 3.2 Market Growth
# The global AI agent market was valued at $5.40 billion in 2024 and is projected to reach $50.31 billion by 2030, driven by enterprise adoption and advancements in AI capabilities.
#
# ## 4. Challenges and Trends
#
# ### 4.1 Challenges
# - **Governance and Security**: Ensuring responsible use of autonomous systems and maintaining security are critical as these systems become more pervasive.
# - **Cost Discipline**: Balancing the costs of deploying and maintaining AI systems with their benefits.
#
# ### 4.2 Trends
# - **Agentic Systems**: The shift towards systems that operate independently, executing tasks without human oversight.
# - **Integration with Tools**: AI agents are increasingly integrated with various systems and tools, enhancing their functionality and adaptability.
#
# ## 5. Conclusion
#
# The developments in AI agents and autonomous systems in 2025 mark a significant advancement in technology and its application across industries. Key players such as Oracle, IBM, and Infosys are leading the charge, driving market growth and innovation. However, challenges related to governance, cost, and security require ongoing attention.
#
# ## 6. Limitations and Further Research
#
# While this report provides a comprehensive overview of the current state of AI agents and autonomous systems, further research is needed to explore long-term implications, ethical considerations, and regulatory frameworks. Additionally, the impact of these technologies on employment and societal structures warrants further investigation.
#
# ## 7. References
#
# - Tredence, "Top 10 AI Agents in 2025."
# - Glean, "How autonomous AI agents enhance campaign planning in 2025."
# - Fast Company, "AI agents 2025 recap: What happened and what to expect next year."
# - Medium, "The Agentic Shift: 2025 Progress and 2026 Trends in Autonomous AI."
#
# This report is formatted professionally with clear headers and bullet points to enhance readability and comprehension.

# %%
# Example Research Query 2: Science
report = run_research(
    "What are the most promising breakthroughs in renewable energy technology? "
    "Include information about solar, wind, and battery storage innovations."
)
# Out:
# ============================================================
# 🔬 RESEARCH AGENT
# ============================================================
#
# 📌 Query: What are the most promising breakthroughs in renewable energy technology? Include information about solar, wind, and battery storage innovations.
#
# ------------------------------------------------------------
# 📋 Planning research...
#
# Research Plan for Investigating Breakthroughs in Renewable Energy Technology
#
# 1. **Key Aspects of the Topic to Investigate:**
#    - Recent advancements in solar energy technology, focusing on efficiency improvements and cost reductions.
#    - Innovations in wind energy, particularly those that enhance energy capture and integration into the grid.
#    - Developments in battery storage technology, with an emphasis on increased storage capacity, reduced costs, and improved sustainability.
#    - Overall impact of these breakthroughs on the renewable energy industry and potential future trends.
#
# 2. **Specific Search Queries to Execute:**
#    - "Recent breakthroughs in solar energy technology 2023"
#    - "Innovations in wind energy technology 2023"
#    - "Advancements in battery storage technology for renewable energy 2023"
#    - "Impact of renewable energy technology breakthroughs on the industry 2023"
#
# 3. **What Information to Look for in Each Search:**
#    - **For Solar Energy Technology:**
#      - Identify new materials or technologies that have improved the efficiency of solar panels.
#      - Look for developments in solar panel manufacturing processes that have reduced costs.
#      - Examine any novel applications of solar technology in diverse environments or industries.
#
#    - **For Wind Energy Technology:**
#      - Search for new turbine designs or materials that increase energy capture efficiency.
#      - Explore innovations in offshore wind technology and integration strategies for the power grid.
#      - Investigate any advancements that address the environmental and aesthetic impacts of wind farms.
#
#    - **For Battery Storage Technology:**
#      - Investigate breakthroughs in battery chemistry that lead to longer lifespan and higher energy density.
#      - Look for cost reduction strategies in battery production and materials.
#      - Evaluate new storage solutions that facilitate the scalability and sustainability of renewable energy.
#
#    - **For Industry Impact and Future Trends:**
#      - Analyze reports or studies that discuss the economic and environmental impact of recent renewable energy innovations.
#      - Look for expert opinions or projections about the future landscape of renewable energy technology.
#      - Identify emerging trends or potential challenges that could influence the adoption of these technologies.
#
# This structured approach will help in gathering comprehensive information about the most promising breakthroughs in renewable energy technology, focusing on solar, wind, and battery storage innovations.
#
# 🔍 Researching (iteration 1)...
# 🔧 Agent requesting tool: web_search
# 🔍 Researching (iteration 2)...
# ✅ Research complete, moving to synthesis...
# 📝 Synthesizing final report...
#
# ============================================================
# 📄 FINAL RESEARCH REPORT
# ============================================================
# # Research Report: Breakthroughs in Renewable Energy Technology (2023)
#
# ## Executive Summary
#
# In 2023, significant advancements in renewable energy technologies have been observed, particularly in solar, wind, and battery storage sectors. Solar energy has achieved new efficiency records with perovskite tandem solar cells, while wind energy innovations include the development of larger turbines and environmentally friendly designs. Battery storage technologies have also progressed, with substantial cost reductions and increased storage capacities. These breakthroughs are pivotal for enhancing renewable energy's efficiency, integration, and commercial viability, supporting broader global adoption.
#
# ## Solar Energy Technology
#
# ### Key Breakthroughs
# - **Perovskite Tandem Solar Cells**: Achieved a record efficiency of 26.81%. These cells promise higher efficiencies and reduced manufacturing costs.
# - **Bifacial Solar Panels**: Capable of capturing light from both sides, increasing energy production by up to 25%. They are particularly effective in reflective environments.
# - **Transparent Solar Panels**: Utilize materials like transparent luminescent solar concentrators, enabling windows and surfaces to generate energy without sacrificing visibility.
#
# ### Insights
# - Perovskite cells, when used in tandem with silicon, are moving towards efficiencies exceeding 30%, significantly outperforming conventional silicon panels.
# - The advancement of bifacial and transparent panels offers new applications in commercial and architectural sectors.
#
# ### Limitations and Further Research
# - Long-term durability and scalability of perovskite cells need further exploration.
# - Development of cost-effective manufacturing processes for transparent solar panels remains a challenge.
#
# ## Wind Energy Technology
#
# ### Key Breakthroughs
# - **Larger Turbines**: Introduction of 18MW turbines, capable of powering 96,000 residents annually.
# - **Innovations in Turbine Design**: Includes bladeless and vertical-axis turbines, which are more eco-friendly and reduce visual impact.
# - **Offshore Wind Technology**: Enhanced designs and materials have increased offshore energy output and feasibility.
#
# ### Insights
# - The shift towards larger and more efficient turbines is crucial for maximizing energy capture and reducing costs.
# - Offshore wind technology advancements are expanding the geographical applicability of wind energy.
#
# ### Limitations and Further Research
# - Continued research is needed on sustainable recycling methods for turbine components.
# - Development of logistics and infrastructure to support large-scale wind farms is essential.
#
# ## Battery Storage Technology
#
# ### Key Breakthroughs
# - **Cost Reduction**: Battery storage costs have decreased by 93% since 2010, making large-scale storage projects more viable.
# - **Increased Capacity**: In 2023, global battery storage capacity doubled, driven by demand from EVs and renewable energy sectors.
# - **Chemistry Innovations**: Introduction of sodium-ion batteries, which use less expensive materials and lower production costs.
#
# ### Insights
# - The decrease in battery costs enhances the competitiveness of renewable energy systems compared to conventional power sources.
# - Sodium-ion and other emerging battery technologies could provide more sustainable options for energy storage.
#
# ### Limitations and Further Research
# - Addressing the environmental impact of battery production and disposal remains a priority.
# - Continued innovation in battery chemistries is necessary to improve energy density and lifecycle.
#
# ## Conclusion
#
# The breakthroughs in renewable energy technology highlight a promising future for the sector, with enhanced efficiency, reduced costs, and expanded applications. However, ongoing research and development are crucial to overcoming existing limitations and ensuring sustainable growth. The integration of these innovations will play a vital role in achieving global energy transition goals.
#
# ## Sources
# - International Renewable Energy Agency (IRENA)
# - National Renewable Energy Laboratory (NREL)
# - Various industry reports and academic publications (as seen in search results)
#
# **Note**: The information provided in this report is based on available data as of 2023 and may be subject to change with further developments in the field.

# %%
# Try your own research query!
custom_query = "What are the current trends in machine learning for healthcare applications?"

report = run_research(custom_query)
# Out:
# ============================================================
# 🔬 RESEARCH AGENT
# ============================================================
#
# 📌 Query: What are the current trends in machine learning for healthcare applications?
#
# ------------------------------------------------------------
# 📋 Planning research...
#
# Research Plan: Current Trends in Machine Learning for Healthcare Applications
#
# 1. **Key Aspects to Investigate:**
#    - Recent advancements in machine learning (ML) techniques used in healthcare.
#    - Specific applications of ML in various healthcare domains (e.g., diagnostics, personalized medicine, patient monitoring).
#    - Challenges and limitations of using ML in healthcare.
#    - Regulatory and ethical considerations in the deployment of ML in healthcare settings.
#    - Examples of successful implementations and case studies.
#
# 2. **Specific Search Queries:**
#    - Query 1: "Recent advancements in machine learning for healthcare 2023"
#    - Query 2: "Machine learning applications in healthcare diagnostics and treatment"
#    - Query 3: "Challenges and ethical considerations of machine learning in healthcare"
#    - Query 4: "Case studies successful machine learning healthcare implementations 2023"
#
# 3. **Information to Look For in Each Search:**
#    - **Query 1:** Identify the latest ML techniques, algorithms, or tools introduced or refined in 2023 for healthcare purposes. Look for articles, academic papers, and conference proceedings that highlight cutting-edge developments.
#
#    - **Query 2:** Focus on identifying how ML is being applied in specific areas of healthcare. Gather information on ML models used for diagnostics (e.g., imaging analysis, disease prediction), treatment personalization, and patient data analysis. Look for detailed explanations of how these applications are improving healthcare outcomes.
#
#    - **Query 3:** Search for articles and papers discussing the limitations and challenges of implementing ML in healthcare, such as data privacy issues, algorithmic bias, and integration with existing healthcare systems. Also, gather information on ongoing debates and solutions regarding ethical considerations.
#
#    - **Query 4:** Look for case studies and real-world examples of successful ML implementations in healthcare. Gather details about the projects, the ML techniques used, the outcomes achieved, and insights into the factors that contributed to their success.
#
# 🔍 Researching (iteration 1)...
# 🔧 Agent requesting tool: web_search
# 🔍 Researching (iteration 2)...
# ✅ Research complete, moving to synthesis...
# 📝 Synthesizing final report...
#
# ============================================================
# 📄 FINAL RESEARCH REPORT
# ============================================================
# # Research Report: Current Trends in Machine Learning for Healthcare Applications
#
# ## Executive Summary
# In 2023, machine learning (ML) continues to revolutionize healthcare, with significant advancements in diagnostics, personalized medicine, remote monitoring, and medical education. Despite these advancements, challenges related to ethical considerations, data privacy, and regulatory compliance persist. This report synthesizes current trends, applications, challenges, and ethical considerations in ML for healthcare, providing a comprehensive overview of its potential and limitations.
#
# ## Table of Contents
# 1. Introduction
# 2. Recent Advancements in Machine Learning
# 3. Applications in Healthcare
#    - Diagnostics
#    - Personalized Medicine
#    - Drug Discovery
# 4. Challenges and Ethical Considerations
# 5. Conclusion
# 6. References
#
# ## 1. Introduction
# Machine learning in healthcare is rapidly evolving, offering new opportunities to enhance patient care, improve diagnostic accuracy, and optimize treatment plans. This report highlights the latest trends and identifies key areas where ML is making a significant impact.
#
# ## 2. Recent Advancements in Machine Learning
# - **Diagnostics and Data Analysis**: In 2023, ML has advanced in processing unstructured medical data, such as X-rays and clinical notes, enabling more accurate diagnostics and predictions of patient outcomes.
# - **Remote Monitoring**: AI tools have improved remote patient monitoring and drug trial analysis, enhancing healthcare delivery efficiency.
# - **Medical Education**: ML is utilized in medical education to personalize learning experiences and improve clinical simulations ([source](https://healthtechmagazine.net/article/2022/12/ai-healthcare-2023-ml-nlp-more-perfcon)).
#
# ## 3. Applications in Healthcare
# ### Diagnostics
# - ML analyzes genomic, clinical, and laboratory data to detect complex disease patterns, leading to early detection and treatment of diseases ([source](https://www.sciencedirect.com/science/article/pii/S2950363925000225)).
#
# ### Personalized Medicine
# - Predictive models optimize treatments based on individual genetic and lifestyle factors, improving therapeutic outcomes and minimizing side effects.
#
# ### Drug Discovery
# - ML accelerates drug discovery through generative algorithms, enabling faster identification of candidate compounds and drug repurposing.
#
# ## 4. Challenges and Ethical Considerations
# - **Data Privacy**: Protecting patient data is critical, with regulations like GDPR and HIPAA providing frameworks, but challenges remain in ensuring compliance.
# - **Algorithmic Bias**: Ensuring fairness and avoiding bias in AI models is crucial to prevent discrimination in healthcare delivery ([source](https://ncmedicaljournal.com/article/120562-machine-learning-in-health-care-ethical-considerations-tied-to-privacy-interpretability-and-bias)).
# - **Transparency and Accountability**: There is a need for explainable AI to improve transparency and accountability in ML applications, with ongoing research focused on enhancing these aspects.
#
# ## 5. Conclusion
# Machine learning holds transformative potential for healthcare, offering advancements in diagnostics, personalized medicine, and drug discovery. However, addressing ethical and regulatory challenges is essential to ensure responsible and effective implementation of ML technologies in healthcare systems.
#
# ## 6. References
# - HealthTech Magazine. "The Current State of AI in Healthcare and Where It's Going in 2023." [source](https://healthtechmagazine.net/article/2022/12/ai-healthcare-2023-ml-nlp-more-perfcon)
# - ScienceDirect. "Harnessing Machine Learning for Improved Diagnosis, Drug Discovery, and Patient Care." [source](https://www.sciencedirect.com/science/article/pii/S2950363925000225)
# - North Carolina Medical Journal. "Machine Learning in Health Care: Ethical Considerations Tied to Privacy, Interpretability, and Bias." [source](https://ncmedicaljournal.com/article/120562-machine-learning-in-health-care-ethical-considerations-tied-to-privacy-interpretability-and-bias)
#
# ## Limitations and Further Research
# - The ongoing evolution of ML technologies means that continuous research is necessary to stay updated on new developments.
# - Further studies are needed to explore the long-term impacts of ML on healthcare outcomes and costs.
# - Research into optimizing regulatory frameworks to better accommodate the rapid pace of technological advancement in ML is crucial.
#
# This report provides a foundational understanding of the current landscape of machine learning applications in healthcare, emphasizing both the opportunities and the challenges that need to be addressed for its successful integration.

# %% [markdown]
# ## 10. Advanced: Streaming Output
#
# For better UX, we can stream the agent's progress in real-time.

# %%
def run_research_streaming(query: str):
    """Execute a research query with streaming output."""
    print("="*60)
    print(f"🔬 RESEARCH AGENT (Streaming Mode)")
    print("="*60)
    print(f"\n📌 Query: {query}\n")
    print("-"*60)

    initial_state = {
        "messages": [],
        "research_query": query,
        "research_plan": "",
        "search_results": [],
        "final_report": "",
        "iteration_count": 0,
    }

    # Stream through the graph
    for event in researcher_agent.stream(initial_state):
        for node_name, node_output in event.items():
            if node_name == "synthesizer" and "final_report" in node_output:
                print("\n" + "="*60)
                print("📄 FINAL RESEARCH REPORT")
                print("="*60)
                print(node_output["final_report"])


# Run with streaming
run_research_streaming("What are the key features and capabilities of LangGraph for building AI agents?")
# Out:
# ============================================================
# 🔬 RESEARCH AGENT (Streaming Mode)
# ============================================================
#
# 📌 Query: What are the key features and capabilities of LangGraph for building AI agents?
#
# ------------------------------------------------------------
# 📋 Planning research...
#
# Research Plan for Investigating LangGraph's Features and Capabilities for Building AI Agents
#
# 1. **Identify Key Aspects to Investigate:**
#    - Definition and Overview: Understand what LangGraph is and its primary purpose.
#    - Core Features: Determine the main functionalities that LangGraph offers for building AI agents.
#    - Capabilities and Advantages: Explore the specific capabilities that distinguish LangGraph from other similar tools.
#    - Use Cases and Applications: Investigate how LangGraph is utilized in real-world scenarios and its effectiveness.
#    - Integration and Compatibility: Examine how LangGraph integrates with other tools and platforms.
#
# 2. **Specific Search Queries to Execute:**
#    - "LangGraph overview and purpose"
#    - "Key features of LangGraph for AI agent development"
#    - "LangGraph capabilities and advantages compared to other AI tools"
#    - "Case studies or examples of LangGraph applications in AI agent building"
#
# 3. **Information to Look For in Each Search:**
#
#    - **Search Query 1: "LangGraph overview and purpose"**
#      - Look for introductory materials, official documentation, and reviews that explain what LangGraph is, its mission, and its primary use cases. This will help in understanding the foundational aspects of the tool.
#
#    - **Search Query 2: "Key features of LangGraph for AI agent development"**
#      - Identify detailed descriptions of the features that LangGraph offers specifically for building AI agents. Focus on functionality such as natural language processing capabilities, machine learning integration, and user interface.
#
#    - **Search Query 3: "LangGraph capabilities and advantages compared to other AI tools"**
#      - Search for comparative analyses, expert reviews, and user testimonials that highlight what makes LangGraph stand out in the AI tools ecosystem. Pay attention to any unique capabilities or efficiency factors.
#
#    - **Search Query 4: "Case studies or examples of LangGraph applications in AI agent building"**
#      - Look for real-world examples, case studies, or user experiences that demonstrate how LangGraph is applied practically. This will provide insights into its effectiveness and adaptability in various industries or scenarios.
#
# By following this structured plan, the investigation will yield a comprehensive understanding of LangGraph's features and capabilities in the context of building AI agents.
#
# 🔍 Researching (iteration 1)...
# 🔧 Agent requesting tool: web_search
# 🔍 Researching (iteration 2)...
# ✅ Research complete, moving to synthesis...
# 📝 Synthesizing final report...
#
# ============================================================
# 📄 FINAL RESEARCH REPORT
# ============================================================
# # LangGraph for Building AI Agents: A Research Report
#
# ## Executive Summary
#
# LangGraph is a powerful framework within the LangChain ecosystem designed to build complex, stateful AI applications using large language models (LLMs). It offers a structured approach through graph-based architectures, making it ideal for developing sophisticated AI agents that require intricate orchestration, decision-making, and state management. This report outlines the key features and capabilities of LangGraph, its advantages over other frameworks, and its practical applications in building AI agents.
#
# ## Table of Contents
#
# 1. Introduction
# 2. Key Features of LangGraph
# 3. Capabilities and Advantages
# 4. Use Cases and Applications
# 5. Integration and Compatibility
# 6. Conclusions
# 7. Limitations and Further Research
# 8. References
#
# ## 1. Introduction
#
# LangGraph is an open-source framework developed as part of the LangChain ecosystem, specifically designed for creating complex AI agent workflows. It utilizes a graph-based architecture for modeling and managing the relationships between various components within an AI agent workflow. This report explores LangGraph's features, capabilities, and advantages, comparing it with other AI frameworks and providing insights into its practical applications.
#
# ## 2. Key Features of LangGraph
#
# - **Graph-Based Architecture**: LangGraph employs a directed graph structure to define application flows. Nodes represent individual processing steps, and edges define transitions between these steps, facilitating complex decision-making and efficient branching logic.
#
# - **State Management**: The framework offers robust state management, allowing for memory and context persistence across interactions. This feature is crucial for maintaining application state and ensuring consistent execution of workflows.
#
# - **Multimodal Processing**: LangGraph supports text, image, and audio processing, enabling rich, multimodal interactions for autonomous agent operations.
#
# - **Human-in-the-Loop**: It allows human interventions and adjustments during workflow execution, providing flexibility and human oversight where needed.
#
# ## 3. Capabilities and Advantages
#
# - **Integration and Compatibility**: LangGraph integrates seamlessly with tools and platforms within the LangChain ecosystem and supports native models like Ollama, HuggingFace, and LlamaCpp.
#
# - **Caching and Efficiency**: Built-in caching allows for the reuse of previously computed results, enhancing performance and reducing latency.
#
# - **Parallel Task Execution**: The framework supports concurrent task execution, improving efficiency in handling complex workflows requiring multiple agents or components.
#
# - **Scalability and Composability**: LangGraph is designed to scale from prototypes to production-grade systems, offering flexibility for a wide range of applications.
#
# ## 4. Use Cases and Applications
#
# LangGraph is particularly advantageous for applications requiring intricate orchestration and decision-making. It is suitable for:
#
# - Developing sophisticated chatbots
# - Multi-agent systems needing stateful interactions
# - Applications requiring robust workflow management and decision-making capabilities
#
# ## 5. Integration and Compatibility
#
# LangGraph is part of the LangChain ecosystem, enabling broad compatibility with existing AI tools and platforms. It supports integration with external databases and cloud storage solutions for enhanced state management and scalability.
#
# ## 6. Conclusions
#
# LangGraph stands out as a framework for building complex AI systems due to its structured approach to workflow management and state handling. It provides developers with comprehensive tools to create reliable, inspectable, and maintainable AI applications, making it a preferred choice for production-ready systems.
#
# ## 7. Limitations and Further Research
#
# While LangGraph offers numerous advantages, further research is recommended in the following areas:
#
# - Exploring its limitations in specific real-world applications
# - Comparing its performance with emerging AI frameworks
# - Investigating potential improvements in integration with other AI ecosystems
#
# ## 8. References
#
# 1. [LangGraph Fundamentals: A Basic Introduction of How to Build AI ...](https://www.youtube.com/watch?v=qkgW_iwdJ_c)
# 2. [What is LangGraph? - IBM](https://www.ibm.com/think/topics/langgraph)
# 3. [LangChain and LangGraph - AWS Prescriptive Guidance](https://docs.aws.amazon.com/prescriptive-guidance/latest/agentic-ai-frameworks/langchain-langgraph.html)
#
# This report provides an overview of LangGraph's capabilities and its role in advancing AI agent development. Further exploration and experimentation will continue to uncover its potential in building complex, intelligent systems.

# %% [markdown]
# ## 11. Summary
#
# In this notebook, we built a **Researcher Agent** using LangGraph with the following components:
#
# ### Architecture
# - **Planner Node**: Analyzes the query and creates a research plan
# - **Researcher Node**: Executes searches based on the plan
# - **Tools Node**: Handles web search tool execution
# - **Synthesizer Node**: Compiles findings into a comprehensive report
#
# ### Key Features
# - ✅ Multi-provider LLM support (OpenAI, Anthropic, Google)
# - ✅ Real-time web search via Tavily API
# - ✅ Structured state management with TypedDict
# - ✅ Conditional routing for iterative research
# - ✅ Professional report synthesis
# - ✅ Streaming output support
#
# ### Next Steps
# - Add more tools (document analysis, academic search)
# - Implement memory for multi-session research
# - Add citation tracking and verification
# - Create a web interface with Gradio or Streamlit

# %%
print("\n🎉 Researcher Agent Example Complete!")
print("\nFeel free to modify the prompts, add more tools, or integrate with other APIs!")
